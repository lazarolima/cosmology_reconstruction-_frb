# %% [markdown]
# # H(z) Reconstrution via Gaussian Process (GP)

# %%
import matplotlib.pyplot as plt
import numpy as np
import gaussian_process as gp
from obs_data import H_data
from equations import FiducialModel

fiducial_model = FiducialModel()

z_values = H_data.z_func()
H_obs = H_data.H_func()
errors = H_data.errors_func()

# Obter valores de predição
mean, var, mean_deriv, var_deriv = gp.pred()

# Modelo LambdaCDM plano
z_test = gp.z_pred()
H_theory = fiducial_model.H_padrao(z_test.flatten())

# Plotar os resultados
plt.figure(figsize=(12, 8))

# Dados originais com barras de erro
plt.errorbar(z_values, H_obs, yerr=errors, fmt='o', capsize=4, color='k', label='Data')

# Função predita pelo GP
plt.plot(z_test, mean, 'k-', label='Reconstrution')

# Adicionar curvas sombreadas de 1σ e 2σ
plt.fill_between(z_test.flatten(), 
                 mean.flatten() - 1*np.sqrt(var.flatten()), 
                 mean.flatten() + 1*np.sqrt(var.flatten()), 
                 alpha=0.3, color='k', label='1σ')
plt.fill_between(z_test.flatten(), 
                 mean.flatten() - 2*np.sqrt(var.flatten()), 
                 mean.flatten() + 2*np.sqrt(var.flatten()), 
                 alpha=0.2, color='gray', label='2σ')

plt.plot(z_test, H_theory, 'b--', label='$\\Lambda$CDM model')

plt.xlabel('Redshift (z)')
plt.ylabel('H(z)')
plt.legend()
plt.grid(True)
plt.savefig('H_reconstructed.png', dpi=600)
# Out:
#  /home/lazarolima/.local/lib/python3.12/site-packages/paramz/transformations.py:111: RuntimeWarning:overflow encountered in expm1

# %% [markdown]
# #### Generating FRBs Mock data

# %%
from mock import RedshiftSimulation
import obs_data as od

# Parâmetros para gerar novos dados
n_new = 500  # Número de novos pontos de dados
z_max = 2  # Máximo redshift

# Criar uma instância da classe RedshiftSimulation
sim = RedshiftSimulation(n_new, z_max)

# Gerar novos dados
sim.generate_redshifts()
sim.simulate_DM_IGM()

# Obter os resultados
new_z = sim.get_new_z()
DM_IGM_sim = sim.get_DM_IGM_sim()

# Obter valores de predição
mean1, var1, mean_deriv1, var_deriv1 = gp.pred_new()

# Plotar os resultados
plt.figure(figsize=(12, 8))

# Dados originais com barras de erro
plt.scatter(new_z, DM_IGM_sim, alpha=0.3, color='k', label='Mock data')
plt.scatter(od.z_obs, od.DM_IGM_obs, color='r', label='Data')

# Função predita pelo GP
plt.plot(gp.z_pred(), mean1, 'k--', label='Reconstrution')

# Adicionar curvas sombreadas de 1σ e 2σ
plt.fill_between(gp.z_pred().flatten(), 
                 mean1.flatten() - 1*np.sqrt(var1.flatten()), 
                 mean1.flatten() + 1*np.sqrt(var1.flatten()), 
                 alpha=0.3, color='k', label='1σ')
plt.fill_between(gp.z_pred().flatten(), 
                 mean1.flatten() - 2*np.sqrt(var1.flatten()), 
                 mean1.flatten() + 2*np.sqrt(var1.flatten()), 
                 alpha=0.2, color='gray', label='2σ')

# Modelo fiducial
# Create an instance of the model
from equations import FiducialModel

model = FiducialModel()

dm_igm_theory = model.DM_IGM(gp.z_pred().flatten())
plt.plot(gp.z_pred(), dm_igm_theory, 'b--', label='Fiducial model')

plt.xlabel('Redshift (z)')
plt.ylabel('$DM_{IGM}$ (pc/cm³)')
plt.legend()
plt.grid(True)
plt.savefig('DM_IGM_reconstructed.png', dpi=600)

# %%
# Plotar as derivadas
plt.figure(figsize=(12, 8))
plt.plot(gp.z_pred(), mean_deriv1.flatten(), 'b-', label='Derivative reconstrution')

# Adicionar curvas sombreadas de 1σ e 2σ para a derivada
plt.fill_between(gp.z_pred().flatten(), 
                 mean_deriv1.flatten() - 1*np.sqrt(var_deriv1.flatten()), 
                 mean_deriv1.flatten() + 1*np.sqrt(var_deriv1.flatten()), 
                 alpha=0.3, color='k', label='1σ')
plt.fill_between(gp.z_pred().flatten(), 
                 mean_deriv1.flatten() - 2*np.sqrt(var_deriv1.flatten()), 
                 mean_deriv1.flatten() + 2*np.sqrt(var_deriv1.flatten()), 
                 alpha=0.2, color='gray', label='2σ')

# Derivada de DM_IGM
dm_igm_deriv = model.I(gp.z_pred().flatten())
plt.plot(gp.z_pred().flatten(), dm_igm_deriv, 'g--', label='Model derivative')

plt.xlabel('Redshift (z)')
plt.ylabel('$dDM_{IGM}/dz$ (pc/cm$^{3}$)')
plt.legend()
plt.grid(True)
plt.savefig('dDM_IGM_reconstructed.png', dpi=600)

# %%
import ultranest
from likelihood import Priors as P, LikelihoodFunction as LF

sampler1 = ultranest.ReactiveNestedSampler(P.parameters1, LF.log_likelihood1, P.prior_transform1)
sampler2 = ultranest.ReactiveNestedSampler(P.parameters2, LF.log_likelihood2, P.prior_transform2)
sampler3 = ultranest.ReactiveNestedSampler(P.parameters2, LF.log_likelihood3, P.prior_transform2)
sampler4 = ultranest.ReactiveNestedSampler(P.parameters3, LF.log_likelihood4, P.prior_transform3)

# %%
result1 = sampler1.run(min_num_live_points=400)
sampler1.print_results()
# Out:
# [ultranest] Sampling 400 live points from prior ...
# VBox(children=(HTML(value=''), GridspecLayout(children=(HTML(value="<div style='background-color:#6E6BF4;'>&nb…
# [ultranest] Explored until L=-8  99 [-7.9898..-7.9898]*| it/evals=2520/2992 eff=97.2222% N=400
# [ultranest] Likelihood function evaluations: 3015
# [ultranest]   logZ = -11.16 +- 0.07114
# [ultranest] Effective samples strategy satisfied (ESS = 1247.1, need >400)
# [ultranest] Posterior uncertainty strategy is satisfied (KL: 0.46+-0.06 nat, need <0.50 nat)
# [ultranest] Evidency uncertainty strategy is satisfied (dlogz=0.08, need <0.5)
# [ultranest]   logZ error budget: single: 0.08 bs:0.07 tail:0.04 total:0.08 required:<0.50
# [ultranest] done iterating.
#
# logZ = -11.164 +- 0.178
#   single instance: logZ = -11.164 +- 0.082
#   bootstrapped   : logZ = -11.156 +- 0.174
#   tail           : logZ = +- 0.041
# insert order U test : converged: True correlation: inf iterations
#
#     $f_{IGM}$           : 0.688 │ ▁   ▁▁▁▁▁▁▂▁▂▃▄▆▅▅▆▇▇▆▆▅▃▃▂▂▁▁▁▁▁▁▁▁▁ │0.840     0.768 +- 0.018

# %%
result2 = sampler2.run(min_num_live_points=400)
sampler2.print_results()
# Out:
# [ultranest] Sampling 400 live points from prior ...
# VBox(children=(HTML(value=''), GridspecLayout(children=(HTML(value="<div style='background-color:#6E6BF4;'>&nb…
# [ultranest] Explored until L=-8  86 [-7.8688..-7.8688]*| it/evals=4360/6044 eff=77.2502% N=400 0    0
# [ultranest] Likelihood function evaluations: 6081
# [ultranest]   logZ = -14.21 +- 0.072
# [ultranest] Effective samples strategy satisfied (ESS = 1527.7, need >400)
# [ultranest] Posterior uncertainty strategy is satisfied (KL: 0.46+-0.05 nat, need <0.50 nat)
# [ultranest] Evidency uncertainty strategy is satisfied (dlogz=0.07, need <0.5)
# [ultranest]   logZ error budget: single: 0.12 bs:0.07 tail:0.01 total:0.07 required:<0.50
# [ultranest] done iterating.
#
# logZ = -14.228 +- 0.183
#   single instance: logZ = -14.228 +- 0.117
#   bootstrapped   : logZ = -14.214 +- 0.183
#   tail           : logZ = +- 0.010
# insert order U test : converged: True correlation: inf iterations
#
#     $f_{IGM}$           : 0.583 │ ▁  ▁▁▁▁▁▁▁▁▁▂▂▃▃▄▄▅▆▇▇▇▇▇▆▆▅▄▂▂▁▁▁▁▁▁ │0.837     0.732 +- 0.031
#     $\alpha$            : 0.000 │▆▅▇▇▇▇▇▆▆▆▇▅▅▄▄▄▃▃▃▃▂▂▂▁▁▁▁▁▁▁▁ ▁▁ ▁▁▁ │0.468     0.112 +- 0.076

# %%
result3 = sampler3.run(min_num_live_points=400)
sampler3.print_results()
# Out:
# [ultranest] Sampling 400 live points from prior ...
# VBox(children=(HTML(value=''), GridspecLayout(children=(HTML(value="<div style='background-color:#6E6BF4;'>&nb…
# [ultranest] Explored until L=-8  97 [-7.9738..-7.9737]*| it/evals=4160/5798 eff=77.0656% N=400 0
# [ultranest] Likelihood function evaluations: 5824
# [ultranest]   logZ = -13.8 +- 0.08389
# [ultranest] Effective samples strategy satisfied (ESS = 1568.7, need >400)
# [ultranest] Posterior uncertainty strategy is satisfied (KL: 0.46+-0.08 nat, need <0.50 nat)
# [ultranest] Evidency uncertainty strategy is satisfied (dlogz=0.08, need <0.5)
# [ultranest]   logZ error budget: single: 0.11 bs:0.08 tail:0.01 total:0.08 required:<0.50
# [ultranest] done iterating.
#
# logZ = -13.817 +- 0.164
#   single instance: logZ = -13.817 +- 0.111
#   bootstrapped   : logZ = -13.798 +- 0.164
#   tail           : logZ = +- 0.010
# insert order U test : converged: True correlation: inf iterations
#
#     $f_{IGM}$           : 0.536 │ ▁  ▁▁▁▁▁▁▁▁▁▁▂▂▂▃▃▅▄▅▆▇▆▇▇▇▆▅▄▃▂▁▁▁ ▁ │0.840     0.723 +- 0.039
#     $\alpha$            : 0.00  │▆▆▇▆▇▅▆▅▄▅▄▃▃▃▃▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁  ▁ │0.81      0.18 +- 0.13

# %%
result4 = sampler4.run(min_num_live_points=400)
sampler4.print_results()
# Out:
# [ultranest] Sampling 400 live points from prior ...
# VBox(children=(HTML(value=''), GridspecLayout(children=(HTML(value="<div style='background-color:#6E6BF4;'>&nb…
# [ultranest] Explored until L=-8  81 [-7.8167..-7.8166]*| it/evals=4840/8502 eff=59.7383% N=400 0  0  0    0
# [ultranest] Likelihood function evaluations: 8512
# [ultranest]   logZ = -15.35 +- 0.06916
# [ultranest] Effective samples strategy satisfied (ESS = 1540.3, need >400)
# [ultranest] Posterior uncertainty strategy is satisfied (KL: 0.46+-0.05 nat, need <0.50 nat)
# [ultranest] Evidency uncertainty strategy is satisfied (dlogz=0.07, need <0.5)
# [ultranest]   logZ error budget: single: 0.13 bs:0.07 tail:0.01 total:0.07 required:<0.50
# [ultranest] done iterating.
#
# logZ = -15.326 +- 0.123
#   single instance: logZ = -15.326 +- 0.128
#   bootstrapped   : logZ = -15.347 +- 0.123
#   tail           : logZ = +- 0.010
# insert order U test : converged: True correlation: inf iterations
#
#     $f_{IGM}$           : 0.448 │ ▁▁ ▁▁▁▁▁▁▁▁▁▁▂▃▃▄▄▄▅▅▇▇▇▇▆▇▇▆▆▅▄▄▃▂▂▁▂│1.000     0.808 +- 0.086
#     $s$                 : -0.294│ ▁  ▁  ▁  ▁▁▁▁▁▁▁▁▁▁▂▂▂▃▄▄▄▇▇▇▇▇▇▅▄▂▁▁ │0.126     0.016 +- 0.045

# %%
from getdist import plots, MCSamples

# Extraindo amostras dos resultados
samples1 = result1['samples']
samples2 = result2['samples']
samples3 = result3['samples']
samples4 = result4['samples']

# Criando objetos MCSamples com os dados
labels1 = ['f_{IGM,0}']
names1 = ['f_IGM']
mcsamples1 = MCSamples(samples=samples1, names=names1, labels=labels1)

labels2 = ['f_{IGM,0}', '\\alpha']
names2 = ['f_IGM', 'alpha']
mcsamples2 = MCSamples(samples=samples2, names=names2, labels=labels2)
mcsamples3 = MCSamples(samples=samples3, names=names2, labels=labels2)

labels3 = ['f_{IGM,0}', 's']
names3 = ['f_IGM', 's']
mcsamples4 = MCSamples(samples=samples4, names=names3, labels=labels3)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
# Plotando os Triangle plots
g = plots.get_subplot_plotter()
mcsamples1.updateSettings({'smooth_scale_2D': 0.9, 'smooth_scale_1D': 0.9})
g.settings.num_plot_contours = 2
g.triangle_plot(mcsamples1, filled=True, contour_colors=['green'], 
                legend_labels=['P. 1'], 
                title_limit=1)
g.export('Figuras/H_p1.png', dpi=600)

# %%
# Plotando os Triangle plots
g = plots.get_subplot_plotter()
mcsamples2.updateSettings({'smooth_scale_2D': 0.9, 'smooth_scale_1D': 0.9})
g.settings.num_plot_contours = 2
g.triangle_plot(mcsamples2, filled=True, contour_colors=['red'],
                legend_labels=['P. 2'], title_limit=1)
g.export('Figuras/H_p2.png', dpi=600)

# %%
# Plotando os Triangle plots
g = plots.get_subplot_plotter()
mcsamples3.updateSettings({'smooth_scale_2D': 0.9, 'smooth_scale_1D': 0.9})
g.settings.num_plot_contours = 2
g.triangle_plot(mcsamples3, filled=True, contour_colors=['blue'],
                legend_labels=['P. 3'], title_limit=1)
g.export('Figuras/H_p3.png', dpi=600)

# %%
# Plotando os Triangle plots
g = plots.get_subplot_plotter()
mcsamples4.updateSettings({'smooth_scale_2D': 0.9, 'smooth_scale_1D': 0.9})
g.settings.num_plot_contours = 2
g.triangle_plot(mcsamples4, filled=True, contour_colors=['purple'],
                legend_labels=['P. 4'], title_limit=1)
g.export('Figuras/H_p4.png', dpi=600)

# %%
from ultranest.plot import PredictionBand
from equations import H_Model

plt.figure()
plt.xlabel('$z$')
plt.ylabel('H(z)')
plt.errorbar(x=z_values, y=H_obs, yerr=errors, marker='o', capsize=3, ls=' ', color='purple', label='$DM_{ext}^{obs}$')

band = PredictionBand(z_test.flatten())

# go through the solutions
for f_IGM  in sampler1.results['samples']:
    # compute for each time the y value
    model = H_Model()
    band.add(model.H_p1(z_test.flatten(), f_IGM=f_IGM))

band.line(color='k', linestyle='--', label='$H_{P1}$', linewidth=1.5)
# add 1 sigma quantile
band.shade(color='k', alpha=0.3)
# add wider quantile (0.01 .. 0.99)
band.shade(q=0.49, color='gray', alpha=0.2)

plt.legend()
plt.savefig('Figuras/H_bestfit.png', format='png', dpi=600)
# Out:
#  /home/lazarolima/.local/lib/python3.12/site-packages/GPy/core/gp.py:285: SyntaxWarning:invalid escape sequence '\m'
#  /home/lazarolima/.local/lib/python3.12/site-packages/GPy/core/gp.py:291: SyntaxWarning:invalid escape sequence '\i'
#  /home/lazarolima/.local/lib/python3.12/site-packages/GPy/core/gp.py:701: SyntaxWarning:invalid escape sequence '\m'
#  /home/lazarolima/.local/lib/python3.12/site-packages/GPy/core/gp.py:717: SyntaxWarning:invalid escape sequence '\m'
#  /home/lazarolima/.local/lib/python3.12/site-packages/GPy/kern/src/stationary.py:24: SyntaxWarning:invalid escape sequence '\e'
#  /home/lazarolima/.local/lib/python3.12/site-packages/GPy/kern/src/stationary.py:152: SyntaxWarning:invalid escape sequence '\s'
#  /home/lazarolima/.local/lib/python3.12/site-packages/GPy/kern/src/stationary.py:255: SyntaxWarning:invalid escape sequence '\p'
#  /home/lazarolima/.local/lib/python3.12/site-packages/GPy/kern/src/stationary.py:294: SyntaxWarning:invalid escape sequence '\p'
#  /home/lazarolima/.local/lib/python3.12/site-packages/GPy/kern/src/stationary.py:421: SyntaxWarning:invalid escape sequence '\e'
#  /home/lazarolima/.local/lib/python3.12/site-packages/GPy/kern/src/stationary.py:458: SyntaxWarning:invalid escape sequence '\e'
#  /home/lazarolima/.local/lib/python3.12/site-packages/GPy/kern/src/stationary.py:557: SyntaxWarning:invalid escape sequence '\s'
#  /home/lazarolima/.local/lib/python3.12/site-packages/GPy/kern/src/stationary.py:624: SyntaxWarning:invalid escape sequence '\s'
#  /home/lazarolima/.local/lib/python3.12/site-packages/GPy/kern/src/stationary.py:665: SyntaxWarning:invalid escape sequence '\s'
#  /home/lazarolima/.local/lib/python3.12/site-packages/GPy/kern/src/stationary.py:683: SyntaxWarning:invalid escape sequence '\s'
#  /home/lazarolima/.local/lib/python3.12/site-packages/GPy/kern/src/stationary.py:718: SyntaxWarning:invalid escape sequence '\s'
#  /home/lazarolima/.local/lib/python3.12/site-packages/GPy/kern/src/stationary.py:740: SyntaxWarning:invalid escape sequence '\s'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 14
#      11 # go through the solutions
#      12 for f_IGM  in sampler1.results['samples']:
#      13     # compute for each time the y value
# ---> 14     model = H_Model()
#      15     band.add(model.H_p1(z_test.flatten(), f_IGM=f_IGM))
#      17 band.line(color='k', linestyle='--', label='$H_{P1}$', linewidth=1.5)
#
# File ~/cosmology_reconstruction_frb/equations.py:63, in H_Model.__init__(self)
#      60 self.factor = fiducial_model.factor
#      62 # Using the derivative of DM_IGM(z) via Gaussin Process
# ---> 63 mean1, var1, mean_deriv1, var_deriv1 = gp.pred_new()
#      64 mean_deriv1 = mean_deriv1.flatten()
#      65 self.mean_deriv1 = mean_deriv1
#
# File ~/cosmology_reconstruction_frb/gaussian_process.py:72, in pred_new()
#      70 def pred_new():
#      71     mean1, var1 = m1.predict(z_pred())
# ---> 72     mean_deriv1, var_deriv1 = m1.predict_jacobian(z_pred())
#      73     return mean1, var1, mean_deriv1, var_deriv1
#
# File ~/.local/lib/python3.12/site-packages/GPy/core/gp.py:511, in GP.predict_jacobian(self, Xnew, kern, full_cov)
#     509 one = np.ones((1,1))
#     510 for i in range(self._predictive_variable.shape[0]):
# --> 511     dK_dXnew_full[i] = kern.gradients_X(one, Xnew, self._predictive_variable[[i]])
#     513 if full_cov:
#     514     dK2_dXdX = kern.gradients_XX(one, Xnew)
#
# File ~/.local/lib/python3.12/site-packages/GPy/kern/src/kernel_slice_operations.py:150, in _slice_gradients_X.<locals>.wrap(self, dL_dK, X, X2)
#     147 @wraps(f)
#     148 def wrap(self, dL_dK, X, X2=None):
#     149     with _Slice_wrap(self, X, X2) as s:
# --> 150         ret = s.handle_return_array(f(self, dL_dK, s.X, s.X2))
#     151     return ret
#
# File ~/.local/lib/python3.12/site-packages/GPy/kern/src/stationary.py:250, in Stationary.gradients_X(self, dL_dK, X, X2)
#     246 """
#     247 Given the derivative of the objective wrt K (dL_dK), compute the derivative wrt X
#     248 """
#     249 if use_stationary_cython:
# --> 250     return self._gradients_X_cython(dL_dK, X, X2)
#     251 else:
#     252     return self._gradients_X_pure(dL_dK, X, X2)
#
# File ~/.local/lib/python3.12/site-packages/GPy/kern/src/stationary.py:357, in Stationary._gradients_X_cython(self, dL_dK, X, X2)
#     355 X, X2 = np.ascontiguousarray(X), np.ascontiguousarray(X2)
#     356 grad = np.zeros(X.shape)
# --> 357 stationary_cython.grad_X(X.shape[0], X.shape[1], X2.shape[0], X, X2, tmp, grad)
#     358 return grad/self.lengthscale**2
#
# KeyboardInterrupt:
